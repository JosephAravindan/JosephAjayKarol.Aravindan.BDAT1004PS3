# %% [markdown]
# # Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import pandas as pd

us_marriage_divorce_data = pd.read_csv('C:\\Users\\josep\\Downloads\\us-marriages-divorces-1867-2014.csv')
us_marriage_divorce_data = us_marriage_divorce_data[
    us_marriage_divorce_data['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = us_marriage_divorce_data['Year'].values
marriages_per_capita = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce_data['Divorces_per_1000'].values
df_marraige_divorce_VBAR = pd.DataFrame(list(zip( marriages_per_capita , divorces_per_capita )),
                  index = years , 
                  columns = [ 'marriages_per_capita' , 'divorces_per_capita' ])

df_marraige_divorce_VBAR
# Out:
#       marriages_per_capita  divorces_per_capita
# 1900                   9.3                  0.7
# 1950                  11.0                  2.5
# 2000                   8.2                  3.3

# %%
df_marraige_divorce_VBAR.plot.bar(xlabel='YEAR', ylabel='Values Per Capita',figsize=(20,10), title='Marriage and Divorce per Capita in US - 1900, 1950, and 2000')
# Out:
# <AxesSubplot:title={'center':'Marriage and Divorce per Capita in US - 1900, 1950, and 2000'}, xlabel='YEAR', ylabel='Values Per Capita'>
